# %% [markdown]
# <a href="https://colab.research.google.com/github/dannxdr/DALC_Scala/blob/main/DALC_HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Matplotlib
# - 파이썬의 대표적인 시각화 도구
# - 파이썬에서 그래프 표시를 가능하게 함

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')

# %%
plt.style.use('classic')

# %%
plt.savefig('my_figure.jpg')

# %%
from google.colab import files
files.download('my_figure.jpg')

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt 
plt.style.use('seaborn-whitegrid') 
import numpy as np

# %%
fig = plt.figure()  
fig.suptitle("Example : Line spot") 
ax = plt.axes()

# %%
plt.plot(x,y);
ax = plt.axes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3e1d064df707> in <module>()
# ----> 1 plt.plot(x,y);
#       2
#       3 ax = plt.axes()
#
# NameError: name 'x' is not defined

# %% [markdown]
# plt.plot(x,np.sin(x))
#
# plt.plot(x,np.cos(x))

# %%
# 레이블 추가
plt.plot(x, np.cos(x))
plt.title("A Cosine")
plt.xlabel("x") #x축 라벨 이름
plt.ylabel("sin(x)"); #y축 라벨 이름
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5bbab60eae6d> in <module>()
#       1 # 레이블 추가
# ----> 2 plt.plot(x, np.cos(x))
#       3 plt.title("A Cosine")
#       4 plt.xlabel("x") #x축 라벨 이름
#       5 plt.ylabel("sin(x)"); #y축 라벨 이름
#
# NameError: name 'x' is not defined

# %%
#점 그림 그리는 방법
plt.plot(x, np.sin(x),'-og');

# %%
#다중 서브 플롯
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
nrows,nclos=3,4

# %%
fig = plt.figure()
fig.subplots_adjust
(hspace=0.4,wspace=0.4)
# Out:
#   File "<ipython-input-32-fe5397e23bae>", line 3
#     (hspace=0.4,wspace=0.4)
#            ^
# SyntaxError: invalid syntax

# %%
nrows,ncols=3,4
fig,ax = plt.subplots(nrows,ncols,sharex='col', sharey='row')
