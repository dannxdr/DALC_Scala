# %% [markdown]
# <a href="https://colab.research.google.com/github/dannxdr/DALC_Scala/blob/main/Colab_%EC%8B%A4%EC%8A%B5_%EC%9E%90%EB%A3%8C_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 실습 하기

# %% [markdown]
# ## 1. 마크다운으로 내 깃허브 링크 삽입하기
#
# (https://github.com/dannxdr)

# %% [markdown]
# ## 2. 마크다운으로 이미지 삽입하기
#
# - 이미지는 인터넷에 있는 이미지 아무거나 또는 내 pc에 저장되어 있는 아무이미지를 삽입해주시면 됩니다.
#
# (여기를 채워주세요!![KakaoTalk_20210312_120155812.jpg](data:image/jpeg;base64,...))

# %% [markdown]
# # 3. 마크다운으로 수업 배운 것 정리해보기
# - 전공수업, 교양 수업, 오늘 ot내용, 요즘 준비하는 자격증 내용 등등 기타 자기가 최근 배운 것 아무거나 최소 3줄이상 작성해주세요. (이때 단어강조하기, 문장 띄어쓰기, 인용구등 사용하기)
#
# (실용프랑스어 1주차 강의 수강하였음
# > 프랑스어는 너무 어렵고
# >> 너무 재미없다
#
# __조사방법론__ 실시간 줌 수업 하였음
#
# __문화콘텐츠창의성__ ocu 수강
# > 문콘창이 상한 꿀이라던데...
